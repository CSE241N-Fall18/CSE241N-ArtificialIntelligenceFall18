# %%
import pickle
l1 = [1,2,3]
l2 = [4,5,6]
fo = open("a.pickle","wb")
pickle.dump(l1,fo)
fo.close()

# %%
fo = open("a.pickle","wb")
pickle.dump(l2,fo)
fo.close()

# %%
fo = open("a.pickle","rb")
k = pickle.load(fo)
fo.close()
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-6-59764cae68ba> in <module>()
#       1 fo = open("a.pickle","rb")
# ----> 2 k = pickle.load(fo)
#       3 fo.close()
#
# EOFError: Ran out of input
