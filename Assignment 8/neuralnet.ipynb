# %%
# %run -i grad_check.py
# Out:
# gradients for W1 match?: True
# gradients for b1 match?: True
# gradients for W2 match?: True
# gradients for b2 match?: True
# gradients for W3 match?: True
# gradients for b3 match?: True
# gradients for W4 match?: True
# gradients for b4 match?: True
# Implementation is working correctly!

# %%
# %run -i main.py
# Out:
# -----E[000]	Time 0.0	Loss 1154.2(1154.2)	Prec 0.436(0.436)
# Validation Precision: 0.4666666666666667
# -----E[001]	Time 0.0	Loss 723.1(723.1)	Prec 0.445(0.445)
# Validation Precision: 0.5666666666666667
# -----E[002]	Time 0.0	Loss 556.6(556.6)	Prec 0.529(0.529)
# Validation Precision: 0.6416666666666667
# -----E[003]	Time 0.0	Loss 438.7(438.7)	Prec 0.586(0.586)
# Validation Precision: 0.6333333333333333
# -----E[004]	Time 0.0	Loss 363.5(363.5)	Prec 0.612(0.612)
# Validation Precision: 0.6416666666666667
# -----E[005]	Time 0.0	Loss 315.4(315.4)	Prec 0.650(0.650)
# Validation Precision: 0.675
# -----E[006]	Time 0.1	Loss 275.9(275.9)	Prec 0.695(0.695)
# Validation Precision: 0.6916666666666667
# -----E[007]	Time 0.1	Loss 245.8(245.8)	Prec 0.724(0.724)
# Validation Precision: 0.7
# -----E[008]	Time 0.1	Loss 223.6(223.6)	Prec 0.743(0.743)
# Validation Precision: 0.7
# -----E[009]	Time 0.1	Loss 206.7(206.7)	Prec 0.774(0.774)
# Validation Precision: 0.7083333333333334
# ...
